# %%
import rasterio
from matplotlib import pyplot as plt
from rasterio.plot import show
from rasterio.mask import mask

image_file = "guano.tif"

my_image = rasterio.open(image_file)
my_image

show(my_image)
